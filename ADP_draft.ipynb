# %% [markdown]
# <a href="https://colab.research.google.com/github/alexk2206/Data_Driven_Fantasy_Football/blob/dev/ADP_draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1  Initialisierung und Konfiguration

# %% [markdown]
# ## 1.1 Bibliotheken installieren und laden

# %%
import pandas as pd
import numpy as np
import re
import random
from math import ceil
import time
import json
# !pip install rapidfuzz
from rapidfuzz import process

# %% [markdown]
# ## 1.2 Liga-Parameter und Rahmenbedingungen definieren

# %%
year = 2024
num_teams = 12
num_rounds = 15
num_weeks = 17
allowed_positions = {'QB', 'RB', 'WR', 'TE', 'K', 'DST'}
lineup_req = {'QB': 1, 'RB': 2, 'WR': 2, 'TE': 1, 'FLEX': 1, 'K': 1, 'DST': 1}

# %% [markdown]
# # 2 Datenbeschaffung und -vorverarbeitung

# %% [markdown]
# ## 2.1 ADP, Bye Weeks und Projections laden

# %%
adp_url = f'https://raw.githubusercontent.com/alexk2206/Data_Driven_Fantasy_Football/refs/heads/main/pre_season_data/adp_projections_{year}.csv'
player_adp = (
    pd.read_csv(adp_url)
      .rename(columns={'player': 'Player', 'position': 'POS', 'adp': 'ADP', 'points': 'TTL'})
      .fillna({'ADP': 999})
      .loc[:, ['Player', 'POS', 'ADP', 'TTL']]
      .sort_values(by = ['ADP', 'TTL'], ascending = [True, False])
      .reset_index(drop=True)
      .drop_duplicates(subset='Player', keep='first')
)
player_adp['Rank'] = player_adp.index + 1

real_data_RZ_url = f'https://raw.githubusercontent.com/alexk2206/Data_Driven_Fantasy_Football/refs/heads/dev/Weekly_Data/weekly_data_{year}.csv'
real_data_RZ = (
    pd.read_csv(real_data_RZ_url)
    .rename(columns={'position': 'POS', 'player_display_name': 'Player'})
    .replace({'FB': 'RB'})
    .drop(columns = ['season'], errors='ignore')
    .loc[lambda real_data_RZ: real_data_RZ['POS'].isin(allowed_positions)]
)


real_data_FP_url = f'https://raw.githubusercontent.com/alexk2206/Data_Driven_Fantasy_Football/refs/heads/main/Weekly_Data/FantasyPros_Fantasy_Football_Points_PPR_{year}.csv'
real_data_FP = (
    pd.read_csv(real_data_FP_url)
      .rename(columns={'Pos': 'POS', 'player_display_name': 'Player'})
      .replace({'-': 0, 'BYE': 0})
      .drop(columns = ['#', 'Team'], errors='ignore')
      .query("POS in ['K', 'DST']")
)

real_data_FP = real_data_FP.melt(
    id_vars=['Player', 'POS'],
    value_vars=[str(w) for w in range(1, 18)],
    var_name='week',
    value_name='fantasy_points_ppr'
)
real_data_FP = real_data_FP[~real_data_FP['fantasy_points_ppr'].isin(['BYE', '-', None])].copy()
real_data_FP['fantasy_points_ppr'] = pd.to_numeric(real_data_FP['fantasy_points_ppr'])
real_data = pd.concat([real_data_FP, real_data_RZ], ignore_index=True)

print("Positions in Fantasy Pros Data:")
print(real_data_FP['POS'].value_counts())
print("\nPositions in Row Zero Data:")
print(real_data_RZ['POS'].value_counts())
print("\nPositions in Concatonated Data")
print(real_data['POS'].value_counts())

real_projections_url = f'https://raw.githubusercontent.com/alexk2206/Data_Driven_Fantasy_Football/refs/heads/main/real_projections/real_projections_{year}.csv'
real_projections = (
    pd.read_csv(real_projections_url)
      .rename(columns={'player': 'Player', 'position': 'POS', 'points': 'Projection', 'week': 'Week'})
      .loc[:, ['Player', 'POS', 'Projection', 'Week']]
      .pivot_table(
         index=['Player', 'POS'],
         columns='Week',
         values='Projection',
         aggfunc='first'
      )
      .rename_axis(None, axis=1)
      .add_prefix('Week_')
      .reset_index()
      .fillna(0)
      .drop_duplicates(subset='Player', keep='first')
)
# Out:
# Positions in Fantasy Pros Data:
# POS
# K      765
# DST    544
# Name: count, dtype: int64
#
# Positions in Row Zero Data:
# POS
# WR    2152
# RB    1505
# TE    1094
# QB     651
# Name: count, dtype: int64
#
# Positions in Concatonated Data
# POS
# WR     2152
# RB     1505
# TE     1094
# K       765
# QB      651
# DST     544
# Name: count, dtype: int64

# %%
adp_names = player_adp['Player'].unique().tolist()
adp_pos_dict = dict(zip(player_adp['Player'], player_adp['POS']))

def match_name_with_pos(name, pos, reference_list, reference_pos_dict, cutoff=85.5):
    filtered_candidates = [p for p in reference_list if reference_pos_dict.get(p) == pos]
    result = process.extractOne(name, filtered_candidates, score_cutoff=cutoff)
    return result[0] if result else None

real_data['Player'] = real_data.apply(
    lambda row: match_name_with_pos(row['Player'], row['POS'], adp_names, adp_pos_dict),
    axis=1
)
real_data = real_data.drop_duplicates(subset=['Player', 'POS', 'week'], keep='first')

real_data = real_data[real_data['Player'].notnull()].copy()

# %%
print(player_adp.head())
print(real_projections.head())
print(real_data.head())
# print(real_data_FP.head())
# print(real_data_RZ.head())
# Out:
#                 Player POS   ADP    TTL  Rank
# 0  Christian McCaffrey  RB  1.92  399.0     1
# 1       Saquon Barkley  RB  2.13  339.0     2
# 2      Ezekiel Elliott  RB  3.44  322.0     3
# 3         Alvin Kamara  RB  4.22  301.0     4
# 4          Dalvin Cook  RB  7.95  304.0     5
#         Player  POS  Week_1  Week_2  Week_3  Week_4  Week_5  Week_6   Week_7  \
# 0        49ers  DST   6.040   6.460   6.080   5.350   5.670   38.60   4.6800
# 1   A.J. Brown   WR  13.800   0.000   0.000   0.000  14.800   68.50  15.3000
# 2   A.J. Green   WR  15.300  15.400  14.300  11.700   9.800   54.60  11.1000
# 3    AJ Dillon   RB   3.390   2.520   1.350   1.010   0.000   36.70   5.2800
# 4  AJ McCarron   QB   0.115   0.147   0.111   0.151   0.194    3.59   0.0302
#
#    Week_8    Week_9   Week_10   Week_11  Week_12  Week_13  Week_14  Week_15  \
# 0    4.58   3.37000   3.39000   0.00000     4.08    4.780    4.660    4.900
# 1   16.50  16.50000  17.80000  16.90000    17.20   18.200   18.100   18.700
# 2   11.30   0.00000   9.40000   9.09000     8.18    7.150    6.760    6.310
# 3    3.77   0.00000   1.94000   1.53000     0.11    0.111    0.116    0.631
# 4    0.00   0.00504   0.00504   0.00504     0.00    0.000    0.000    0.000
#
#    Week_16
# 0     3.88
# 1   104.00
# 2     8.72
# 3     2.11
# 4     0.00
#            Player POS week  fantasy_points_ppr
# 0   Jason Sanders   K    1                 4.0
# 1    Younghoe Koo   K    1                 9.0
# 2      Tyler Bass   K    1                 9.0
# 3  Daniel Carlson   K    1                12.0
# 4   Greg Zuerlein   K    1                 5.0

# %%
# # Alle Zeilen mit unterschiedlichem Namen
# mismatched = real_data[real_data['Player'] != real_data['Player_cleaned']]

# # Optional: Doppelte Kombinationen entfernen
# unique_mismatched = mismatched[['Player', 'Player_cleaned']].drop_duplicates()

# # Sortiert anzeigen
# unique_mismatched = unique_mismatched

# # Ausgabe
# unique_mismatched

# %% [markdown]
# # Simulate League

# %%
teams         = [f'Team {i+1}' for i in range(num_teams)]
num_reg_weeks = 14
playoff_weeks = [15, 16, 17]

def create_reg_schedule(teams):
    n = len(teams)
    schedule = []
    for week in range(num_reg_weeks):
        week_matches = []
        for i in range(n//2):
            team1 = teams[i]
            team2 = teams[n-1-i]
            week_matches.append((team1, team2))
        schedule.append(week_matches)
        # Rotate teams except the first one
        teams = [teams[0]] + [teams[-1]] + teams[1:-1]
    return schedule

reg_schedule = create_reg_schedule(teams)

# %%
def simulate_league(seed, num_teams, num_rounds, player_adp, real_projections, real_data, reg_schedule):
    import random
    import pandas as pd

    random.seed(seed)

    teams = [f'Team {i+1}' for i in range(num_teams)]
    players_list = player_adp['Player'].copy().tolist()
    pos = dict(zip(player_adp['Player'], player_adp['POS']))
    df_sorted = player_adp.sort_values('Rank').reset_index(drop=True)

    draft_order = []
    for rnd in range(num_rounds):
        order = teams if rnd % 2 == 0 else teams[::-1]
        draft_order += order

    lineup_req = {'QB': 1, 'RB': 2, 'WR': 2, 'TE': 1, 'K': 1, 'DST': 1, 'FLEX': 1}
    min_roster_req = lineup_req.copy()
    min_roster_req['RB'] += 1
    min_roster_req['WR'] += 1
    min_roster_req['TE'] += 1

    def opponent_pick(roster, available, Rk, min_req, picks_remaining, round_number):
        pos_counts = {p: sum(1 for pl in roster if pos[pl] == p) for p in min_req}
        needed = {p: max(0, min_req[p] - pos_counts.get(p, 0)) for p in min_req}
        total_needed = sum(needed.values())

        if total_needed >= picks_remaining:
            for p in sorted(needed, key=lambda k: needed[k], reverse=True):
                candidates = [pl for pl in available if pos[pl] == p]
                if candidates:
                    return min(candidates, key=lambda x: Rk[x])
        remaining_players = sorted(available, key=lambda p: Rk[p])
        topk = min(len(remaining_players), max(1, round_number * 2))
        return random.choice(remaining_players[:topk])

    rosters = {tm: [] for tm in teams}
    available = set(players_list)
    draft_log = []

    for pick_idx, team in enumerate(draft_order, start=1):
        rank_dict = dict(zip(df_sorted['Player'], df_sorted['Rank']))
        remaining_players = sorted(available, key=lambda p: rank_dict.get(p, float('inf')))
        Rk = {p: i + 1 for i, p in enumerate(remaining_players)}
        picks_remaining = num_rounds - len(rosters[team])
        current_round = (pick_idx - 1) // len(teams) + 1

        pick = opponent_pick(
            roster=rosters[team],
            available=available,
            Rk=Rk,
            min_req=min_roster_req,
            picks_remaining=picks_remaining,
            round_number=current_round
        )

        rosters[team].append(pick)
        available.remove(pick)
        draft_log.append({
            'Pick': pick_idx,
            'Team': team,
            'Player': pick,
            'Round': current_round,
            'POS': pos[pick],
            'ADP': player_adp.loc[player_adp['Player'] == pick, 'ADP'].values[0]
        })

    df_draft = pd.DataFrame(draft_log)
    roster_weekly_projections = (
        df_draft
        .merge(real_projections.drop(columns='POS'), on='Player', how='left')
        .sort_values(by=['Team', 'Pick'])
        .reset_index(drop=True)
    )

    def get_best_lineup(team, week, roster_weekly_projections, lineup_req):
        week_col = f'Week_{week}'
        team_roster = roster_weekly_projections[roster_weekly_projections['Team'] == team]
        lineup = []
        used_players = set()
        for pos, limit in lineup_req.items():
            if pos != 'FLEX':
                candidates = team_roster[team_roster['POS'] == pos]
            else:
                candidates = team_roster[
                    (team_roster['POS'].isin(['RB', 'WR', 'TE'])) &
                    (~team_roster['Player'].isin(used_players))
                ]
            starters = candidates.sort_values(week_col, ascending=False).head(limit)
            lineup.append(starters)
            used_players.update(starters['Player'])
        return pd.concat(lineup)

    def get_actual_points(lineup, week, real_data):
        merged = lineup.merge(
            real_data[real_data['week'] == week],
            left_on='Player', right_on='Player', how='left'
        )
        merged['fantasy_points_ppr'] = merged['fantasy_points_ppr'].fillna(0)
        return merged['fantasy_points_ppr'].sum()

    results = []
    for week_idx, matchups in enumerate(reg_schedule, 1):
        for team1, team2 in matchups:
            lineup1 = get_best_lineup(team1, week_idx, roster_weekly_projections, lineup_req)
            lineup2 = get_best_lineup(team2, week_idx, roster_weekly_projections, lineup_req)
            points1 = get_actual_points(lineup1, week_idx, real_data)
            points2 = get_actual_points(lineup2, week_idx, real_data)
            winner = team1 if points1 > points2 else team2 if points2 > points1 else 'Unentschieden'
            results.append({'Woche': week_idx, 'Sieger': winner})

    df_results = pd.DataFrame(results)
    wins = df_results[df_results['Sieger'] != 'Unentschieden']['Sieger'].value_counts()
    record = pd.DataFrame({'Team': teams})
    record['Wins'] = record['Team'].map(wins).fillna(0).astype(int)
    record = record.sort_values(by=['Wins'], ascending=[False]).reset_index(drop=True)
    ranked_teams = record['Team'].tolist()

    week15 = [(ranked_teams[2], ranked_teams[5]), (ranked_teams[3], ranked_teams[4])]
    winners15 = []
    for team1, team2 in week15:
        p1 = get_actual_points(get_best_lineup(team1, 15, roster_weekly_projections, lineup_req), 15, real_data)
        p2 = get_actual_points(get_best_lineup(team2, 15, roster_weekly_projections, lineup_req), 15, real_data)
        winner = team1 if p1 > p2 else team2
        winners15.append(winner)

    week16 = [(winners15[0], ranked_teams[1]), (winners15[1], ranked_teams[0])]
    winners16 = []
    for team1, team2 in week16:
        p1 = get_actual_points(get_best_lineup(team1, 16, roster_weekly_projections, lineup_req), 16, real_data)
        p2 = get_actual_points(get_best_lineup(team2, 16, roster_weekly_projections, lineup_req), 16, real_data)
        winner = team1 if p1 > p2 else team2
        winners16.append(winner)

    team1, team2 = winners16
    p1 = get_actual_points(get_best_lineup(team1, 17, roster_weekly_projections, lineup_req), 17, real_data)
    p2 = get_actual_points(get_best_lineup(team2, 17, roster_weekly_projections, lineup_req), 17, real_data)
    champion = team1 if p1 > p2 else team2

    points_for_summary = []
    for team in teams:
        points_reg_season = 0
        points_full_season = 0
        for week in range(1, 18):
            lineup = get_best_lineup(team, week, roster_weekly_projections, lineup_req)
            total_points = get_actual_points(lineup, week, real_data)
            if week <= 14:
                points_reg_season += total_points
            points_full_season += total_points
        points_for_summary.append({
            'Team': team,
            'Points Reg Season': round(points_reg_season, 2),
            'Points Full Season': round(points_full_season, 2)
        })

    df_points = pd.DataFrame(points_for_summary)
    df_champ_roster = df_draft[df_draft['Team'] == champion][['Player', 'ADP']]
    champion_roster = [f"{row.Player} / {row.ADP:.2f}" for row in df_champ_roster.itertuples()]
    points_row = df_points[df_points['Team'] == champion].iloc[0]

    return {
        'Winner': champion,
        'Roster': champion_roster,
        'Points Reg Season': points_row['Points Reg Season'],
        'Points Full Season': points_row['Points Full Season']
    }

# %%
# #For 2020 (16 Weeks)

# teams         = [f'Team {i+1}' for i in range(num_teams)]
# num_reg_weeks = 13
# playoff_weeks = [14, 15, 16]

# def create_reg_schedule(teams):
#     n = len(teams)
#     schedule = []
#     for week in range(num_reg_weeks):
#         week_matches = []
#         for i in range(n//2):
#             team1 = teams[i]
#             team2 = teams[n-1-i]
#             week_matches.append((team1, team2))
#         schedule.append(week_matches)
#         # Rotate teams except the first one
#         teams = [teams[0]] + [teams[-1]] + teams[1:-1]
#     return schedule

# reg_schedule = create_reg_schedule(teams)

# def simulate_league(seed, num_teams, num_rounds, player_adp, real_projections, real_data, reg_schedule):
#     import random
#     import pandas as pd

#     random.seed(seed)

#     teams = [f'Team {i+1}' for i in range(num_teams)]
#     players_list = player_adp['Player'].copy().tolist()
#     pos = dict(zip(player_adp['Player'], player_adp['POS']))
#     df_sorted = player_adp.sort_values('Rank').reset_index(drop=True)

#     draft_order = []
#     for rnd in range(num_rounds):
#         order = teams if rnd % 2 == 0 else teams[::-1]
#         draft_order += order

#     lineup_req = {'QB': 1, 'RB': 2, 'WR': 2, 'TE': 1, 'K': 1, 'DST': 1, 'FLEX': 1}
#     min_roster_req = lineup_req.copy()
#     min_roster_req['RB'] += 1
#     min_roster_req['WR'] += 1
#     min_roster_req['TE'] += 1

#     def opponent_pick(roster, available, Rk, min_req, picks_remaining, round_number):
#         pos_counts = {p: sum(1 for pl in roster if pos[pl] == p) for p in min_req}
#         needed = {p: max(0, min_req[p] - pos_counts.get(p, 0)) for p in min_req}
#         total_needed = sum(needed.values())

#         if total_needed >= picks_remaining:
#             for p in sorted(needed, key=lambda k: needed[k], reverse=True):
#                 candidates = [pl for pl in available if pos[pl] == p]
#                 if candidates:
#                     return min(candidates, key=lambda x: Rk[x])
#         remaining_players = sorted(available, key=lambda p: Rk[p])
#         topk = min(len(remaining_players), max(1, round_number * 2))
#         return random.choice(remaining_players[:topk])

#     rosters = {tm: [] for tm in teams}
#     available = set(players_list)
#     draft_log = []

#     for pick_idx, team in enumerate(draft_order, start=1):
#         rank_dict = dict(zip(df_sorted['Player'], df_sorted['Rank']))
#         remaining_players = sorted(available, key=lambda p: rank_dict.get(p, float('inf')))
#         Rk = {p: i + 1 for i, p in enumerate(remaining_players)}
#         picks_remaining = num_rounds - len(rosters[team])
#         current_round = (pick_idx - 1) // len(teams) + 1

#         pick = opponent_pick(
#             roster=rosters[team],
#             available=available,
#             Rk=Rk,
#             min_req=min_roster_req,
#             picks_remaining=picks_remaining,
#             round_number=current_round
#         )

#         rosters[team].append(pick)
#         available.remove(pick)
#         draft_log.append({
#             'Pick': pick_idx,
#             'Team': team,
#             'Player': pick,
#             'Round': current_round,
#             'POS': pos[pick],
#             'ADP': player_adp.loc[player_adp['Player'] == pick, 'ADP'].values[0]
#         })

#     df_draft = pd.DataFrame(draft_log)
#     roster_weekly_projections = (
#         df_draft
#         .merge(real_projections.drop(columns='POS'), on='Player', how='left')
#         .sort_values(by=['Team', 'Pick'])
#         .reset_index(drop=True)
#     )

#     def get_best_lineup(team, week, roster_weekly_projections, lineup_req):
#         week_col = f'Week_{week}'
#         team_roster = roster_weekly_projections[roster_weekly_projections['Team'] == team]
#         lineup = []
#         used_players = set()
#         for pos, limit in lineup_req.items():
#             if pos != 'FLEX':
#                 candidates = team_roster[team_roster['POS'] == pos]
#             else:
#                 candidates = team_roster[
#                     (team_roster['POS'].isin(['RB', 'WR', 'TE'])) &
#                     (~team_roster['Player'].isin(used_players))
#                 ]
#             starters = candidates.sort_values(week_col, ascending=False).head(limit)
#             lineup.append(starters)
#             used_players.update(starters['Player'])
#         return pd.concat(lineup)

#     def get_actual_points(lineup, week, real_data):
#         merged = lineup.merge(
#             real_data[real_data['week'] == week],
#             left_on='Player', right_on='Player', how='left'
#         )
#         merged['fantasy_points_ppr'] = merged['fantasy_points_ppr'].fillna(0)
#         return merged['fantasy_points_ppr'].sum()

#     results = []
#     for week_idx, matchups in enumerate(reg_schedule, 1):
#         for team1, team2 in matchups:
#             lineup1 = get_best_lineup(team1, week_idx, roster_weekly_projections, lineup_req)
#             lineup2 = get_best_lineup(team2, week_idx, roster_weekly_projections, lineup_req)
#             points1 = get_actual_points(lineup1, week_idx, real_data)
#             points2 = get_actual_points(lineup2, week_idx, real_data)
#             winner = team1 if points1 > points2 else team2 if points2 > points1 else 'Unentschieden'
#             results.append({'Woche': week_idx, 'Sieger': winner})

#     df_results = pd.DataFrame(results)
#     wins = df_results[df_results['Sieger'] != 'Unentschieden']['Sieger'].value_counts()
#     record = pd.DataFrame({'Team': teams})
#     record['Wins'] = record['Team'].map(wins).fillna(0).astype(int)
#     record = record.sort_values(by=['Wins'], ascending=[False]).reset_index(drop=True)
#     ranked_teams = record['Team'].tolist()

#     week15 = [(ranked_teams[2], ranked_teams[5]), (ranked_teams[3], ranked_teams[4])]
#     winners15 = []
#     for team1, team2 in week15:
#         p1 = get_actual_points(get_best_lineup(team1, 14, roster_weekly_projections, lineup_req), 14, real_data)
#         p2 = get_actual_points(get_best_lineup(team2, 14, roster_weekly_projections, lineup_req), 14, real_data)
#         winner = team1 if p1 > p2 else team2
#         winners15.append(winner)

#     week16 = [(winners15[0], ranked_teams[1]), (winners15[1], ranked_teams[0])]
#     winners16 = []
#     for team1, team2 in week16:
#         p1 = get_actual_points(get_best_lineup(team1, 15, roster_weekly_projections, lineup_req), 15, real_data)
#         p2 = get_actual_points(get_best_lineup(team2, 15, roster_weekly_projections, lineup_req), 15, real_data)
#         winner = team1 if p1 > p2 else team2
#         winners16.append(winner)

#     team1, team2 = winners16
#     p1 = get_actual_points(get_best_lineup(team1, 16, roster_weekly_projections, lineup_req), 16, real_data)
#     p2 = get_actual_points(get_best_lineup(team2, 16, roster_weekly_projections, lineup_req), 16, real_data)
#     champion = team1 if p1 > p2 else team2

#     points_for_summary = []
#     for team in teams:
#         points_reg_season = 0
#         points_full_season = 0
#         for week in range(1, 17):
#             lineup = get_best_lineup(team, week, roster_weekly_projections, lineup_req)
#             total_points = get_actual_points(lineup, week, real_data)
#             if week <= 14:
#                 points_reg_season += total_points
#             points_full_season += total_points
#         points_for_summary.append({
#             'Team': team,
#             'Points Reg Season': round(points_reg_season, 2),
#             'Points Full Season': round(points_full_season, 2)
#         })

#     df_points = pd.DataFrame(points_for_summary)
#     df_champ_roster = df_draft[df_draft['Team'] == champion][['Player', 'ADP']]
#     champion_roster = [f"{row.Player} / {row.ADP:.2f}" for row in df_champ_roster.itertuples()]
#     points_row = df_points[df_points['Team'] == champion].iloc[0]

#     return {
#         'Winner': champion,
#         'Roster': champion_roster,
#         'Points Reg Season': points_row['Points Reg Season'],
#         'Points Full Season': points_row['Points Full Season']
#     }

# %%
num_batches = 10
num_simulations = 50
year = 2020

for batch_number in range(1, num_batches + 1):
    base_seed = (batch_number - 1) * num_simulations
    simulation_results = []
    champions = []

    for i in range(num_simulations):
        seed = base_seed + i + 1
        print(f"\nBatch {batch_number}, Simulation {i + 1} started...")
        start_time = time.time()

        sim_result = simulate_league(
            seed=seed,
            num_teams=num_teams,
            num_rounds=num_rounds,
            player_adp=player_adp,
            real_projections=real_projections,
            real_data=real_data,
            reg_schedule=reg_schedule
        )

        elapsed = round(time.time() - start_time, 2)

        simulation_results.append({
            'Simulation': i + 1,
            'Winner': sim_result['Winner'],
            'Roster': sim_result['Roster'],
            'Points Reg Season': sim_result['Points Reg Season'],
            'Points Full Season': sim_result['Points Full Season']
        })

        champions.append(sim_result['Winner'])
        print(f"  Done in {elapsed} seconds.")

    df_batch = pd.DataFrame(simulation_results)

    output_filename = f"simulation_results_ADP_{batch_number}_{year}.json"
    df_batch.to_json(output_filename, orient='records', indent=2)
    print(f"\n✅ Batch {batch_number} gespeichert unter: {output_filename}")
# Out:
# Batch 1, Simulation 1 started...
#   Done in 4.02 seconds.
#
# Batch 1, Simulation 2 started...
#   Done in 4.21 seconds.
#
# Batch 1, Simulation 3 started...
#   Done in 5.27 seconds.
#
# Batch 1, Simulation 4 started...
#   Done in 3.54 seconds.
#
# Batch 1, Simulation 5 started...
#   Done in 3.83 seconds.
#
# Batch 1, Simulation 6 started...
#   Done in 4.49 seconds.
#
# Batch 1, Simulation 7 started...
#   Done in 3.86 seconds.
#
# Batch 1, Simulation 8 started...
#   Done in 3.57 seconds.
#
# Batch 1, Simulation 9 started...
#   Done in 3.59 seconds.
#
# Batch 1, Simulation 10 started...
#   Done in 4.26 seconds.
#
# Batch 1, Simulation 11 started...
#   Done in 3.8 seconds.
#
# Batch 1, Simulation 12 started...
#   Done in 3.63 seconds.
#
# Batch 1, Simulation 13 started...
#   Done in 4.86 seconds.
#
# Batch 1, Simulation 14 started...
#   Done in 3.8 seconds.
#
# Batch 1, Simulation 15 started...
#   Done in 3.77 seconds.
#
# Batch 1, Simulation 16 started...
#   Done in 4.66 seconds.
#
# Batch 1, Simulation 17 started...
#   Done in 3.56 seconds.
#
# Batch 1, Simulation 18 started...
#   Done in 3.67 seconds.
#
# Batch 1, Simulation 19 started...
#   Done in 4.33 seconds.
#
# Batch 1, Simulation 20 started...
#   Done in 3.55 seconds.
#
# Batch 1, Simulation 21 started...
#   Done in 3.58 seconds.
#
# Batch 1, Simulation 22 started...
#   Done in 3.94 seconds.
#
# Batch 1, Simulation 23 started...
#   Done in 4.39 seconds.
#
# Batch 1, Simulation 24 started...
#   Done in 3.66 seconds.
#
# Batch 1, Simulation 25 started...
#   Done in 3.56 seconds.
#
# Batch 1, Simulation 26 started...
#   Done in 4.32 seconds.
#
# Batch 1, Simulation 27 started...
#   Done in 3.47 seconds.
#
# Batch 1, Simulation 28 started...
#   Done in 3.53 seconds.
#
# Batch 1, Simulation 29 started...
#   Done in 4.42 seconds.
#
# Batch 1, Simulation 30 started...
#   Done in 3.46 seconds.
#
# Batch 1, Simulation 31 started...
#   Done in 3.6 seconds.
#
# Batch 1, Simulation 32 started...
#   Done in 4.08 seconds.
#
# Batch 1, Simulation 33 started...
#   Done in 3.93 seconds.
#
# Batch 1, Simulation 34 started...
#   Done in 3.49 seconds.
#
# Batch 1, Simulation 35 started...
#   Done in 3.65 seconds.
#
# Batch 1, Simulation 36 started...
#   Done in 5.4 seconds.
#
# Batch 1, Simulation 37 started...
#   Done in 4.14 seconds.
#
# Batch 1, Simulation 38 started...
#   Done in 4.87 seconds.
#
# Batch 1, Simulation 39 started...
#   Done in 4.13 seconds.
#
# Batch 1, Simulation 40 started...
#   Done in 3.51 seconds.
#
# Batch 1, Simulation 41 started...
#   Done in 3.4 seconds.
#
# Batch 1, Simulation 42 started...
#   Done in 4.28 seconds.
#
# Batch 1, Simulation 43 started...
#   Done in 3.41 seconds.
#
# Batch 1, Simulation 44 started...
#   Done in 3.39 seconds.
#
# Batch 1, Simulation 45 started...
#   Done in 3.89 seconds.
#
# Batch 1, Simulation 46 started...
#   Done in 3.79 seconds.
#
# Batch 1, Simulation 47 started...
#   Done in 3.52 seconds.
#
# Batch 1, Simulation 48 started...
#   Done in 3.47 seconds.
#
# Batch 1, Simulation 49 started...
#   Done in 4.37 seconds.
#
# Batch 1, Simulation 50 started...
#   Done in 3.44 seconds.
#
# ✅ Batch 1 gespeichert unter: simulation_results_ADP_1_2024.json
#
# Batch 2, Simulation 1 started...
#   Done in 3.46 seconds.
#
# Batch 2, Simulation 2 started...
#   Done in 4.31 seconds.
#
# Batch 2, Simulation 3 started...
#   Done in 3.6 seconds.
#
# Batch 2, Simulation 4 started...
#   Done in 3.47 seconds.
#
# Batch 2, Simulation 5 started...
#   Done in 3.81 seconds.
#
# Batch 2, Simulation 6 started...
#   Done in 4.19 seconds.
#
# Batch 2, Simulation 7 started...
#   Done in 3.68 seconds.
#
# Batch 2, Simulation 8 started...
#   Done in 3.41 seconds.
#
# Batch 2, Simulation 9 started...
#   Done in 4.39 seconds.
#
# Batch 2, Simulation 10 started...
#   Done in 3.5 seconds.
#
# Batch 2, Simulation 11 started...
#   Done in 3.53 seconds.
#
# Batch 2, Simulation 12 started...
#   Done in 4.03 seconds.
#
# Batch 2, Simulation 13 started...
#   Done in 3.87 seconds.
#
# Batch 2, Simulation 14 started...
#   Done in 3.47 seconds.
#
# Batch 2, Simulation 15 started...
#   Done in 3.62 seconds.
#
# Batch 2, Simulation 16 started...
#   Done in 4.25 seconds.
#
# Batch 2, Simulation 17 started...
#   Done in 3.46 seconds.
#
# Batch 2, Simulation 18 started...
#   Done in 3.5 seconds.
#
# Batch 2, Simulation 19 started...
#   Done in 4.36 seconds.
#
# Batch 2, Simulation 20 started...
#   Done in 3.48 seconds.
#
# Batch 2, Simulation 21 started...
#   Done in 3.49 seconds.
#
# Batch 2, Simulation 22 started...
#   Done in 3.97 seconds.
#
# Batch 2, Simulation 23 started...
#   Done in 3.95 seconds.
#
# Batch 2, Simulation 24 started...
#   Done in 3.38 seconds.
#
# Batch 2, Simulation 25 started...
#   Done in 3.39 seconds.
#
# Batch 2, Simulation 26 started...
#   Done in 4.18 seconds.
#
# Batch 2, Simulation 27 started...
#   Done in 3.32 seconds.
#
# Batch 2, Simulation 28 started...
#   Done in 3.58 seconds.
#
# Batch 2, Simulation 29 started...
#   Done in 4.05 seconds.
#
# Batch 2, Simulation 30 started...
#   Done in 3.75 seconds.
#
# Batch 2, Simulation 31 started...
#   Done in 3.4 seconds.
#
# Batch 2, Simulation 32 started...
#   Done in 3.32 seconds.
#
# Batch 2, Simulation 33 started...
#   Done in 4.27 seconds.
#
# Batch 2, Simulation 34 started...
#   Done in 3.62 seconds.
#
# Batch 2, Simulation 35 started...
#   Done in 3.38 seconds.
#
# Batch 2, Simulation 36 started...
#   Done in 4.04 seconds.
#
# Batch 2, Simulation 37 started...
#   Done in 3.61 seconds.
#
# Batch 2, Simulation 38 started...
#   Done in 3.28 seconds.
#
# Batch 2, Simulation 39 started...
#   Done in 3.33 seconds.
#
# Batch 2, Simulation 40 started...
#   Done in 4.22 seconds.
#
# Batch 2, Simulation 41 started...
#   Done in 3.39 seconds.
#
# Batch 2, Simulation 42 started...
#   Done in 3.6 seconds.
#
# Batch 2, Simulation 43 started...
#   Done in 4.43 seconds.
#
# Batch 2, Simulation 44 started...
#   Done in 3.58 seconds.
#
# Batch 2, Simulation 45 started...
#   Done in 3.33 seconds.
#
# Batch 2, Simulation 46 started...
#   Done in 3.52 seconds.
#
# Batch 2, Simulation 47 started...
#   Done in 4.26 seconds.
#
# Batch 2, Simulation 48 started...
#   Done in 3.36 seconds.
#
# Batch 2, Simulation 49 started...
#   Done in 3.38 seconds.
#
# Batch 2, Simulation 50 started...
#   Done in 4.5 seconds.
#
# ✅ Batch 2 gespeichert unter: simulation_results_ADP_2_2024.json
#
# Batch 3, Simulation 1 started...
#   Done in 3.56 seconds.
#
# Batch 3, Simulation 2 started...
#   Done in 3.53 seconds.
#
# Batch 3, Simulation 3 started...
#   Done in 4.25 seconds.
#
# Batch 3, Simulation 4 started...
#   Done in 4.06 seconds.
#
# Batch 3, Simulation 5 started...
#   Done in 3.59 seconds.
#
# Batch 3, Simulation 6 started...
#   Done in 3.44 seconds.
#
# Batch 3, Simulation 7 started...
#   Done in 4.46 seconds.
#
# Batch 3, Simulation 8 started...
#   Done in 3.52 seconds.
#
# Batch 3, Simulation 9 started...
#   Done in 3.38 seconds.
#
# Batch 3, Simulation 10 started...
#   Done in 4.38 seconds.
#
# Batch 3, Simulation 11 started...
#   Done in 3.28 seconds.
#
# Batch 3, Simulation 12 started...
#   Done in 3.33 seconds.
#
# Batch 3, Simulation 13 started...
#   Done in 3.32 seconds.
#
# Batch 3, Simulation 14 started...
#   Done in 4.21 seconds.
#
# Batch 3, Simulation 15 started...
#   Done in 3.41 seconds.
#
# Batch 3, Simulation 16 started...
#   Done in 3.58 seconds.
#
# Batch 3, Simulation 17 started...
#   Done in 4.28 seconds.
#
# Batch 3, Simulation 18 started...
#   Done in 3.38 seconds.
#
# Batch 3, Simulation 19 started...
#   Done in 3.48 seconds.
#
# Batch 3, Simulation 20 started...
#   Done in 3.88 seconds.
#
# Batch 3, Simulation 21 started...
#   Done in 3.93 seconds.
#
# Batch 3, Simulation 22 started...
#   Done in 3.46 seconds.
#
# Batch 3, Simulation 23 started...
#   Done in 3.43 seconds.
#
# Batch 3, Simulation 24 started...
#   Done in 4.27 seconds.
#
# Batch 3, Simulation 25 started...
#   Done in 3.38 seconds.
#
# Batch 3, Simulation 26 started...
#   Done in 3.33 seconds.
#
# Batch 3, Simulation 27 started...
#   Done in 3.69 seconds.
#
# Batch 3, Simulation 28 started...
#   Done in 3.93 seconds.
#
# Batch 3, Simulation 29 started...
#   Done in 3.49 seconds.
#
# Batch 3, Simulation 30 started...
#   Done in 3.39 seconds.
#
# Batch 3, Simulation 31 started...
#   Done in 4.21 seconds.
#
# Batch 3, Simulation 32 started...
#   Done in 3.4 seconds.
#
# Batch 3, Simulation 33 started...
#   Done in 3.41 seconds.
#
# Batch 3, Simulation 34 started...
#   Done in 3.9 seconds.
#
# Batch 3, Simulation 35 started...
#   Done in 3.74 seconds.
#
# Batch 3, Simulation 36 started...
#   Done in 3.39 seconds.
#
# Batch 3, Simulation 37 started...
#   Done in 3.34 seconds.
#
# Batch 3, Simulation 38 started...
#   Done in 4.44 seconds.
#
# Batch 3, Simulation 39 started...
#   Done in 3.33 seconds.
#
# Batch 3, Simulation 40 started...
#   Done in 3.36 seconds.
#
# Batch 3, Simulation 41 started...
#   Done in 3.98 seconds.
#
# Batch 3, Simulation 42 started...
#   Done in 3.68 seconds.
#
# Batch 3, Simulation 43 started...
#   Done in 3.34 seconds.
#
# Batch 3, Simulation 44 started...
#   Done in 3.4 seconds.
#
# Batch 3, Simulation 45 started...
#   Done in 4.37 seconds.
#
# Batch 3, Simulation 46 started...
#   Done in 3.34 seconds.
#
# Batch 3, Simulation 47 started...
#   Done in 3.4 seconds.
#
# Batch 3, Simulation 48 started...
#   Done in 3.85 seconds.
#
# Batch 3, Simulation 49 started...
#   Done in 3.64 seconds.
#
# Batch 3, Simulation 50 started...
#   Done in 3.43 seconds.
#
# ✅ Batch 3 gespeichert unter: simulation_results_ADP_3_2024.json
#
# Batch 4, Simulation 1 started...
#   Done in 3.43 seconds.
#
# Batch 4, Simulation 2 started...
#   Done in 4.21 seconds.
#
# Batch 4, Simulation 3 started...
#   Done in 3.29 seconds.
#
# Batch 4, Simulation 4 started...
#   Done in 3.4 seconds.
#
# Batch 4, Simulation 5 started...
#   Done in 3.98 seconds.
#
# Batch 4, Simulation 6 started...
#   Done in 3.82 seconds.
#
# Batch 4, Simulation 7 started...
#   Done in 3.6 seconds.
#
# Batch 4, Simulation 8 started...
#   Done in 3.41 seconds.
#
# Batch 4, Simulation 9 started...
#   Done in 4.38 seconds.
#
# Batch 4, Simulation 10 started...
#   Done in 3.67 seconds.
#
# Batch 4, Simulation 11 started...
#   Done in 3.34 seconds.
#
# Batch 4, Simulation 12 started...
#   Done in 4.11 seconds.
#
# Batch 4, Simulation 13 started...
#   Done in 3.41 seconds.
#
# Batch 4, Simulation 14 started...
#   Done in 3.37 seconds.
#
# Batch 4, Simulation 15 started...
#   Done in 3.44 seconds.
#
# Batch 4, Simulation 16 started...
#   Done in 4.2 seconds.
#
# Batch 4, Simulation 17 started...
#   Done in 3.51 seconds.
#
# Batch 4, Simulation 18 started...
#   Done in 3.43 seconds.
#
# Batch 4, Simulation 19 started...
#   Done in 4.22 seconds.
#
# Batch 4, Simulation 20 started...
#   Done in 3.44 seconds.
#
# Batch 4, Simulation 21 started...
#   Done in 3.28 seconds.
#
# Batch 4, Simulation 22 started...
#   Done in 3.45 seconds.
#
# Batch 4, Simulation 23 started...
#   Done in 4.41 seconds.
#
# Batch 4, Simulation 24 started...
#   Done in 3.49 seconds.
#
# Batch 4, Simulation 25 started...
#   Done in 3.41 seconds.
#
# Batch 4, Simulation 26 started...
#   Done in 4.5 seconds.
#
# Batch 4, Simulation 27 started...
#   Done in 3.53 seconds.
#
# Batch 4, Simulation 28 started...
#   Done in 3.42 seconds.
#
# Batch 4, Simulation 29 started...
#   Done in 4.11 seconds.
#
# Batch 4, Simulation 30 started...
#   Done in 3.69 seconds.
#
# Batch 4, Simulation 31 started...
#   Done in 3.35 seconds.
#
# Batch 4, Simulation 32 started...
#   Done in 3.41 seconds.
#
# Batch 4, Simulation 33 started...
#   Done in 4.4 seconds.
#
# Batch 4, Simulation 34 started...
#   Done in 3.33 seconds.
#
# Batch 4, Simulation 35 started...
#   Done in 3.51 seconds.
#
# Batch 4, Simulation 36 started...
#   Done in 4.28 seconds.
#
# Batch 4, Simulation 37 started...
#   Done in 3.64 seconds.
#
# Batch 4, Simulation 38 started...
#   Done in 3.42 seconds.
#
# Batch 4, Simulation 39 started...
#   Done in 3.93 seconds.
#
# Batch 4, Simulation 40 started...
#   Done in 4.13 seconds.
#
# Batch 4, Simulation 41 started...
#   Done in 3.64 seconds.
#
# Batch 4, Simulation 42 started...
#   Done in 3.67 seconds.
#
# Batch 4, Simulation 43 started...
#   Done in 4.48 seconds.
#
# Batch 4, Simulation 44 started...
#   Done in 3.56 seconds.
#
# Batch 4, Simulation 45 started...
#   Done in 3.55 seconds.
#
# Batch 4, Simulation 46 started...
#   Done in 3.99 seconds.
#
# Batch 4, Simulation 47 started...
#   Done in 3.6 seconds.
#
# Batch 4, Simulation 48 started...
#   Done in 3.5 seconds.
#
# Batch 4, Simulation 49 started...
#   Done in 3.5 seconds.
#
# Batch 4, Simulation 50 started...
#   Done in 4.21 seconds.
#
# ✅ Batch 4 gespeichert unter: simulation_results_ADP_4_2024.json
#
# Batch 5, Simulation 1 started...
#   Done in 3.5 seconds.
#
# Batch 5, Simulation 2 started...
#   Done in 3.31 seconds.
#
# Batch 5, Simulation 3 started...
#   Done in 4.25 seconds.
#
# Batch 5, Simulation 4 started...
#   Done in 3.36 seconds.
#
# Batch 5, Simulation 5 started...
#   Done in 3.37 seconds.
#
# Batch 5, Simulation 6 started...
#   Done in 3.38 seconds.
#
# Batch 5, Simulation 7 started...
#   Done in 4.25 seconds.
#
# Batch 5, Simulation 8 started...
#   Done in 3.5 seconds.
#
# Batch 5, Simulation 9 started...
#   Done in 3.41 seconds.
#
# Batch 5, Simulation 10 started...
#   Done in 4.17 seconds.
#
# Batch 5, Simulation 11 started...
#   Done in 3.46 seconds.
#
# Batch 5, Simulation 12 started...
#   Done in 3.45 seconds.
#
# Batch 5, Simulation 13 started...
#   Done in 3.52 seconds.
#
# Batch 5, Simulation 14 started...
#   Done in 4.07 seconds.
#
# Batch 5, Simulation 15 started...
#   Done in 3.38 seconds.
#
# Batch 5, Simulation 16 started...
#   Done in 3.36 seconds.
#
# Batch 5, Simulation 17 started...
#   Done in 4.33 seconds.
#
# Batch 5, Simulation 18 started...
#   Done in 3.39 seconds.
#
# Batch 5, Simulation 19 started...
#   Done in 3.52 seconds.
#
# Batch 5, Simulation 20 started...
#   Done in 3.86 seconds.
#
# Batch 5, Simulation 21 started...
#   Done in 4.22 seconds.
#
# Batch 5, Simulation 22 started...
#   Done in 3.53 seconds.
#
# Batch 5, Simulation 23 started...
#   Done in 3.58 seconds.
#
# Batch 5, Simulation 24 started...
#   Done in 4.3 seconds.
#
# Batch 5, Simulation 25 started...
#   Done in 3.59 seconds.
#
# Batch 5, Simulation 26 started...
#   Done in 3.62 seconds.
#
# Batch 5, Simulation 27 started...
#   Done in 4.69 seconds.
#
# Batch 5, Simulation 28 started...
#   Done in 3.77 seconds.
#
# Batch 5, Simulation 29 started...
#   Done in 3.75 seconds.
#
# Batch 5, Simulation 30 started...
#   Done in 4.2 seconds.
#
# Batch 5, Simulation 31 started...
#   Done in 3.64 seconds.
#
# Batch 5, Simulation 32 started...
#   Done in 3.55 seconds.
#
# Batch 5, Simulation 33 started...
#   Done in 3.68 seconds.
#
# Batch 5, Simulation 34 started...
#   Done in 4.39 seconds.
#
# Batch 5, Simulation 35 started...
#   Done in 3.61 seconds.
#
# Batch 5, Simulation 36 started...
#   Done in 3.68 seconds.
#
# Batch 5, Simulation 37 started...
#   Done in 4.37 seconds.
#
# Batch 5, Simulation 38 started...
#   Done in 3.54 seconds.
#
# Batch 5, Simulation 39 started...
#   Done in 3.48 seconds.
#
# Batch 5, Simulation 40 started...
#   Done in 4.97 seconds.
#
# Batch 5, Simulation 41 started...
#   Done in 3.56 seconds.
#
# Batch 5, Simulation 42 started...
#   Done in 3.43 seconds.
#
# Batch 5, Simulation 43 started...
#   Done in 3.7 seconds.
#
# Batch 5, Simulation 44 started...
#   Done in 4.2 seconds.
#
# Batch 5, Simulation 45 started...
#   Done in 3.63 seconds.
#
# Batch 5, Simulation 46 started...
#   Done in 3.49 seconds.
#
# Batch 5, Simulation 47 started...
#   Done in 4.48 seconds.
#
# Batch 5, Simulation 48 started...
#   Done in 3.58 seconds.
#
# Batch 5, Simulation 49 started...
#   Done in 3.52 seconds.
#
# Batch 5, Simulation 50 started...
#   Done in 4.9 seconds.
#
# ✅ Batch 5 gespeichert unter: simulation_results_ADP_5_2024.json
#
# Batch 6, Simulation 1 started...
#   Done in 3.64 seconds.
#
# Batch 6, Simulation 2 started...
#   Done in 3.63 seconds.
#
# Batch 6, Simulation 3 started...
#   Done in 4.22 seconds.
#
# Batch 6, Simulation 4 started...
#   Done in 4.16 seconds.
#
# Batch 6, Simulation 5 started...
#   Done in 3.62 seconds.
#
# Batch 6, Simulation 6 started...
#   Done in 3.77 seconds.
#
# Batch 6, Simulation 7 started...
#   Done in 4.43 seconds.
#
# Batch 6, Simulation 8 started...
#   Done in 3.74 seconds.
#
# Batch 6, Simulation 9 started...
#   Done in 4.29 seconds.
#
# Batch 6, Simulation 10 started...
#   Done in 5.33 seconds.
#
# Batch 6, Simulation 11 started...
#   Done in 3.88 seconds.
#
# Batch 6, Simulation 12 started...
#   Done in 4.45 seconds.
#
# Batch 6, Simulation 13 started...
#   Done in 4.53 seconds.
#
# Batch 6, Simulation 14 started...
#   Done in 3.84 seconds.
#
# Batch 6, Simulation 15 started...
#   Done in 4.17 seconds.
#
# Batch 6, Simulation 16 started...
#   Done in 4.47 seconds.
#
# Batch 6, Simulation 17 started...
#   Done in 3.67 seconds.
#
# Batch 6, Simulation 18 started...
#   Done in 3.52 seconds.
#
# Batch 6, Simulation 19 started...
#   Done in 4.98 seconds.
#
# Batch 6, Simulation 20 started...
#   Done in 4.68 seconds.
#
# Batch 6, Simulation 21 started...
#   Done in 3.87 seconds.
#
# Batch 6, Simulation 22 started...
#   Done in 4.99 seconds.
#
# Batch 6, Simulation 23 started...
#   Done in 4.19 seconds.
#
# Batch 6, Simulation 24 started...
#   Done in 3.61 seconds.
#
# Batch 6, Simulation 25 started...
#   Done in 4.89 seconds.
#
# Batch 6, Simulation 26 started...
#   Done in 4.49 seconds.
#
# Batch 6, Simulation 27 started...
#   Done in 3.71 seconds.
#
# Batch 6, Simulation 28 started...
#   Done in 4.73 seconds.
#
# Batch 6, Simulation 29 started...
#   Done in 4.05 seconds.
#
# Batch 6, Simulation 30 started...
#   Done in 3.49 seconds.
#
# Batch 6, Simulation 31 started...
#   Done in 4.39 seconds.
#
# Batch 6, Simulation 32 started...
#   Done in 3.75 seconds.
#
# Batch 6, Simulation 33 started...
#   Done in 4.16 seconds.
#
# Batch 6, Simulation 34 started...
#   Done in 4.56 seconds.
#
# Batch 6, Simulation 35 started...
#   Done in 4.19 seconds.
#
# Batch 6, Simulation 36 started...
#   Done in 3.91 seconds.
#
# Batch 6, Simulation 37 started...
#   Done in 4.79 seconds.
#
# Batch 6, Simulation 38 started...
#   Done in 4.1 seconds.
#
# Batch 6, Simulation 39 started...
#   Done in 3.72 seconds.
#
# Batch 6, Simulation 40 started...
#   Done in 4.46 seconds.
#
# Batch 6, Simulation 41 started...
#   Done in 3.72 seconds.
#
# Batch 6, Simulation 42 started...
#   Done in 3.68 seconds.
#
# Batch 6, Simulation 43 started...
#   Done in 4.54 seconds.
#
# Batch 6, Simulation 44 started...
#   Done in 3.91 seconds.
#
# Batch 6, Simulation 45 started...
#   Done in 3.64 seconds.
#
# Batch 6, Simulation 46 started...
#   Done in 3.7 seconds.
#
# Batch 6, Simulation 47 started...
#   Done in 4.09 seconds.
#
# Batch 6, Simulation 48 started...
#   Done in 3.54 seconds.
#
# Batch 6, Simulation 49 started...
#   Done in 3.5 seconds.
#
# Batch 6, Simulation 50 started...
#   Done in 4.68 seconds.
#
# ✅ Batch 6 gespeichert unter: simulation_results_ADP_6_2024.json
#
# Batch 7, Simulation 1 started...
#   Done in 3.58 seconds.
#
# Batch 7, Simulation 2 started...
#   Done in 3.51 seconds.
#
# Batch 7, Simulation 3 started...
#   Done in 4.31 seconds.
#
# Batch 7, Simulation 4 started...
#   Done in 3.7 seconds.
#
# Batch 7, Simulation 5 started...
#   Done in 3.43 seconds.
#
# Batch 7, Simulation 6 started...
#   Done in 3.72 seconds.
#
# Batch 7, Simulation 7 started...
#   Done in 4.32 seconds.
#
# Batch 7, Simulation 8 started...
#   Done in 3.48 seconds.
#
# Batch 7, Simulation 9 started...
#   Done in 3.68 seconds.
#
# Batch 7, Simulation 10 started...
#   Done in 4.46 seconds.
#
# Batch 7, Simulation 11 started...
#   Done in 3.5 seconds.
#
# Batch 7, Simulation 12 started...
#   Done in 3.7 seconds.
#
# Batch 7, Simulation 13 started...
#   Done in 4.34 seconds.
#
# Batch 7, Simulation 14 started...
#   Done in 3.69 seconds.
#
# Batch 7, Simulation 15 started...
#   Done in 3.57 seconds.
#
# Batch 7, Simulation 16 started...
#   Done in 3.7 seconds.
#
# Batch 7, Simulation 17 started...
#   Done in 4.15 seconds.
#
# Batch 7, Simulation 18 started...
#   Done in 3.35 seconds.
#
# Batch 7, Simulation 19 started...
#   Done in 3.47 seconds.
#
# Batch 7, Simulation 20 started...
#   Done in 4.38 seconds.
#
# Batch 7, Simulation 21 started...
#   Done in 3.73 seconds.
#
# Batch 7, Simulation 22 started...
#   Done in 3.86 seconds.
#
# Batch 7, Simulation 23 started...
#   Done in 4.38 seconds.
#
# Batch 7, Simulation 24 started...
#   Done in 3.61 seconds.
#
# Batch 7, Simulation 25 started...
#   Done in 3.66 seconds.
#
# Batch 7, Simulation 26 started...
#   Done in 3.76 seconds.
#
# Batch 7, Simulation 27 started...
#   Done in 4.17 seconds.
#
# Batch 7, Simulation 28 started...
#   Done in 3.51 seconds.
#
# Batch 7, Simulation 29 started...
#   Done in 3.44 seconds.
#
# Batch 7, Simulation 30 started...
#   Done in 4.39 seconds.
#
# Batch 7, Simulation 31 started...
#   Done in 3.78 seconds.
#
# Batch 7, Simulation 32 started...
#   Done in 3.46 seconds.
#
# Batch 7, Simulation 33 started...
#   Done in 4.41 seconds.
#
# Batch 7, Simulation 34 started...
#   Done in 3.38 seconds.
#
# Batch 7, Simulation 35 started...
#   Done in 3.59 seconds.
#
# Batch 7, Simulation 36 started...
#   Done in 3.59 seconds.
#
# Batch 7, Simulation 37 started...
#   Done in 4.24 seconds.
#
# Batch 7, Simulation 38 started...
#   Done in 3.52 seconds.
#
# Batch 7, Simulation 39 started...
#   Done in 3.46 seconds.
#
# Batch 7, Simulation 40 started...
#   Done in 4.5 seconds.
#
# Batch 7, Simulation 41 started...
#   Done in 3.51 seconds.
#
# Batch 7, Simulation 42 started...
#   Done in 3.52 seconds.
#
# Batch 7, Simulation 43 started...
#   Done in 4.15 seconds.
#
# Batch 7, Simulation 44 started...
#   Done in 3.85 seconds.
#
# Batch 7, Simulation 45 started...
#   Done in 3.61 seconds.
#
# Batch 7, Simulation 46 started...
#   Done in 3.76 seconds.
#
# Batch 7, Simulation 47 started...
#   Done in 4.43 seconds.
#
# Batch 7, Simulation 48 started...
#   Done in 3.5 seconds.
#
# Batch 7, Simulation 49 started...
#   Done in 3.91 seconds.
#
# Batch 7, Simulation 50 started...
#   Done in 4.44 seconds.
#
# ✅ Batch 7 gespeichert unter: simulation_results_ADP_7_2024.json
#
# Batch 8, Simulation 1 started...
#   Done in 3.73 seconds.
#
# Batch 8, Simulation 2 started...
#   Done in 3.55 seconds.
#
# Batch 8, Simulation 3 started...
#   Done in 4.46 seconds.
#
# Batch 8, Simulation 4 started...
#   Done in 3.56 seconds.
#
# Batch 8, Simulation 5 started...
#   Done in 3.49 seconds.
#
# Batch 8, Simulation 6 started...
#   Done in 4.55 seconds.
#
# Batch 8, Simulation 7 started...
#   Done in 3.87 seconds.
#
# Batch 8, Simulation 8 started...
#   Done in 3.57 seconds.
#
# Batch 8, Simulation 9 started...
#   Done in 3.55 seconds.
#
# Batch 8, Simulation 10 started...
#   Done in 4.55 seconds.
#
# Batch 8, Simulation 11 started...
#   Done in 3.7 seconds.
#
# Batch 8, Simulation 12 started...
#   Done in 3.82 seconds.
#
# Batch 8, Simulation 13 started...
#   Done in 4.33 seconds.
#
# Batch 8, Simulation 14 started...
#   Done in 3.43 seconds.
#
# Batch 8, Simulation 15 started...
#   Done in 3.49 seconds.
#
# Batch 8, Simulation 16 started...
#   Done in 4.31 seconds.
#
# Batch 8, Simulation 17 started...
#   Done in 3.78 seconds.
#
# Batch 8, Simulation 18 started...
#   Done in 3.51 seconds.
#
# Batch 8, Simulation 19 started...
#   Done in 3.75 seconds.
#
# Batch 8, Simulation 20 started...
#   Done in 4.16 seconds.
#
# Batch 8, Simulation 21 started...
#   Done in 3.46 seconds.
#
# Batch 8, Simulation 22 started...
#   Done in 3.6 seconds.
#
# Batch 8, Simulation 23 started...
#   Done in 4.4 seconds.
#
# Batch 8, Simulation 24 started...
#   Done in 3.7 seconds.
#
# Batch 8, Simulation 25 started...
#   Done in 3.6 seconds.
#
# Batch 8, Simulation 26 started...
#   Done in 4.18 seconds.
#
# Batch 8, Simulation 27 started...
#   Done in 3.59 seconds.
#
# Batch 8, Simulation 28 started...
#   Done in 3.69 seconds.
#
# Batch 8, Simulation 29 started...
#   Done in 3.73 seconds.
#
# Batch 8, Simulation 30 started...
#   Done in 4.55 seconds.
#
# Batch 8, Simulation 31 started...
#   Done in 3.81 seconds.
#
# Batch 8, Simulation 32 started...
#   Done in 3.61 seconds.
#
# Batch 8, Simulation 33 started...
#   Done in 4.44 seconds.
#
# Batch 8, Simulation 34 started...
#   Done in 3.64 seconds.
#
# Batch 8, Simulation 35 started...
#   Done in 3.5 seconds.
#
# Batch 8, Simulation 36 started...
#   Done in 4.37 seconds.
#
# Batch 8, Simulation 37 started...
#   Done in 3.62 seconds.
#
# Batch 8, Simulation 38 started...
#   Done in 3.71 seconds.
#
# Batch 8, Simulation 39 started...
#   Done in 4.07 seconds.
#
# Batch 8, Simulation 40 started...
#   Done in 3.9 seconds.
#
# Batch 8, Simulation 41 started...
#   Done in 3.4 seconds.
#
# Batch 8, Simulation 42 started...
#   Done in 3.62 seconds.
#
# Batch 8, Simulation 43 started...
#   Done in 4.33 seconds.
#
# Batch 8, Simulation 44 started...
#   Done in 3.43 seconds.
#
# Batch 8, Simulation 45 started...
#   Done in 3.33 seconds.
#
# Batch 8, Simulation 46 started...
#   Done in 4.02 seconds.
#
# Batch 8, Simulation 47 started...
#   Done in 3.72 seconds.
#
# Batch 8, Simulation 48 started...
#   Done in 3.56 seconds.
#
# Batch 8, Simulation 49 started...
#   Done in 3.52 seconds.
#
# Batch 8, Simulation 50 started...
#   Done in 4.45 seconds.
#
# ✅ Batch 8 gespeichert unter: simulation_results_ADP_8_2024.json
#
# Batch 9, Simulation 1 started...
#   Done in 3.57 seconds.
#
# Batch 9, Simulation 2 started...
#   Done in 3.43 seconds.
#
# Batch 9, Simulation 3 started...
#   Done in 4.51 seconds.
#
# Batch 9, Simulation 4 started...
#   Done in 3.43 seconds.
#
# Batch 9, Simulation 5 started...
#   Done in 3.47 seconds.
#
# Batch 9, Simulation 6 started...
#   Done in 4.28 seconds.
#
# Batch 9, Simulation 7 started...
#   Done in 3.72 seconds.
#
# Batch 9, Simulation 8 started...
#   Done in 3.38 seconds.
#
# Batch 9, Simulation 9 started...
#   Done in 3.32 seconds.
#
# Batch 9, Simulation 10 started...
#   Done in 4.57 seconds.
#
# Batch 9, Simulation 11 started...
#   Done in 3.37 seconds.
#
# Batch 9, Simulation 12 started...
#   Done in 3.43 seconds.
#
# Batch 9, Simulation 13 started...
#   Done in 4.42 seconds.
#
# Batch 9, Simulation 14 started...
#   Done in 3.57 seconds.
#
# Batch 9, Simulation 15 started...
#   Done in 3.31 seconds.
#
# Batch 9, Simulation 16 started...
#   Done in 3.84 seconds.
#
# Batch 9, Simulation 17 started...
#   Done in 4.17 seconds.
#
# Batch 9, Simulation 18 started...
#   Done in 3.43 seconds.
#
# Batch 9, Simulation 19 started...
#   Done in 3.55 seconds.
#
# Batch 9, Simulation 20 started...
#   Done in 4.23 seconds.
#
# Batch 9, Simulation 21 started...
#   Done in 3.4 seconds.
#
# Batch 9, Simulation 22 started...
#   Done in 3.52 seconds.
#
# Batch 9, Simulation 23 started...
#   Done in 3.88 seconds.
#
# Batch 9, Simulation 24 started...
#   Done in 3.86 seconds.
#
# Batch 9, Simulation 25 started...
#   Done in 3.42 seconds.
#
# Batch 9, Simulation 26 started...
#   Done in 3.58 seconds.
#
# Batch 9, Simulation 27 started...
#   Done in 4.18 seconds.
#
# Batch 9, Simulation 28 started...
#   Done in 3.49 seconds.
#
# Batch 9, Simulation 29 started...
#   Done in 3.5 seconds.
#
# Batch 9, Simulation 30 started...
#   Done in 4.39 seconds.
#
# Batch 9, Simulation 31 started...
#   Done in 3.55 seconds.
#
# Batch 9, Simulation 32 started...
#   Done in 3.75 seconds.
#
# Batch 9, Simulation 33 started...
#   Done in 3.69 seconds.
#
# Batch 9, Simulation 34 started...
#   Done in 4.15 seconds.
#
# Batch 9, Simulation 35 started...
#   Done in 3.8 seconds.
#
# Batch 9, Simulation 36 started...
#   Done in 3.44 seconds.
#
# Batch 9, Simulation 37 started...
#   Done in 4.34 seconds.
#
# Batch 9, Simulation 38 started...
#   Done in 3.64 seconds.
#
# Batch 9, Simulation 39 started...
#   Done in 3.58 seconds.
#
# Batch 9, Simulation 40 started...
#   Done in 4.75 seconds.
#
# Batch 9, Simulation 41 started...
#   Done in 3.55 seconds.
#
# Batch 9, Simulation 42 started...
#   Done in 3.33 seconds.
#
# Batch 9, Simulation 43 started...
#   Done in 3.79 seconds.
#
# Batch 9, Simulation 44 started...
#   Done in 4.11 seconds.
#
# Batch 9, Simulation 45 started...
#   Done in 3.54 seconds.
#
# Batch 9, Simulation 46 started...
#   Done in 3.43 seconds.
#
# Batch 9, Simulation 47 started...
#   Done in 4.38 seconds.
#
# Batch 9, Simulation 48 started...
#   Done in 3.56 seconds.
#
# Batch 9, Simulation 49 started...
#   Done in 3.41 seconds.
#
# Batch 9, Simulation 50 started...
#   Done in 4.0 seconds.
#
# ✅ Batch 9 gespeichert unter: simulation_results_ADP_9_2024.json
#
# Batch 10, Simulation 1 started...
#   Done in 3.85 seconds.
#
# Batch 10, Simulation 2 started...
#   Done in 3.33 seconds.
#
# Batch 10, Simulation 3 started...
#   Done in 3.43 seconds.
#
# Batch 10, Simulation 4 started...
#   Done in 4.4 seconds.
#
# Batch 10, Simulation 5 started...
#   Done in 3.3 seconds.
#
# Batch 10, Simulation 6 started...
#   Done in 3.35 seconds.
#
# Batch 10, Simulation 7 started...
#   Done in 4.2 seconds.
#
# Batch 10, Simulation 8 started...
#   Done in 3.55 seconds.
#
# Batch 10, Simulation 9 started...
#   Done in 3.43 seconds.
#
# Batch 10, Simulation 10 started...
#   Done in 3.64 seconds.
#
# Batch 10, Simulation 11 started...
#   Done in 4.36 seconds.
#
# Batch 10, Simulation 12 started...
#   Done in 3.5 seconds.
#
# Batch 10, Simulation 13 started...
#   Done in 3.61 seconds.
#
# Batch 10, Simulation 14 started...
#   Done in 4.74 seconds.
#
# Batch 10, Simulation 15 started...
#   Done in 3.7 seconds.
#
# Batch 10, Simulation 16 started...
#   Done in 3.5 seconds.
#
# Batch 10, Simulation 17 started...
#   Done in 4.45 seconds.
#
# Batch 10, Simulation 18 started...
#   Done in 3.5 seconds.
#
# Batch 10, Simulation 19 started...
#   Done in 3.71 seconds.
#
# Batch 10, Simulation 20 started...
#   Done in 3.64 seconds.
#
# Batch 10, Simulation 21 started...
#   Done in 4.13 seconds.
#
# Batch 10, Simulation 22 started...
#   Done in 3.7 seconds.
#
# Batch 10, Simulation 23 started...
#   Done in 3.67 seconds.
#
# Batch 10, Simulation 24 started...
#   Done in 4.2 seconds.
#
# Batch 10, Simulation 25 started...
#   Done in 3.46 seconds.
#
# Batch 10, Simulation 26 started...
#   Done in 3.44 seconds.
#
# Batch 10, Simulation 27 started...
#   Done in 4.04 seconds.
#
# Batch 10, Simulation 28 started...
#   Done in 3.71 seconds.
#
# Batch 10, Simulation 29 started...
#   Done in 3.54 seconds.
#
# Batch 10, Simulation 30 started...
#   Done in 3.52 seconds.
#
# Batch 10, Simulation 31 started...
#   Done in 4.32 seconds.
#
# Batch 10, Simulation 32 started...
#   Done in 3.46 seconds.
#
# Batch 10, Simulation 33 started...
#   Done in 3.41 seconds.
#
# Batch 10, Simulation 34 started...
#   Done in 4.24 seconds.
#
# Batch 10, Simulation 35 started...
#   Done in 3.53 seconds.
#
# Batch 10, Simulation 36 started...
#   Done in 3.44 seconds.
#
# Batch 10, Simulation 37 started...
#   Done in 3.76 seconds.
#
# Batch 10, Simulation 38 started...
#   Done in 4.41 seconds.
#
# Batch 10, Simulation 39 started...
#   Done in 3.52 seconds.
#
# Batch 10, Simulation 40 started...
#   Done in 3.34 seconds.
#
# Batch 10, Simulation 41 started...
#   Done in 4.38 seconds.
#
# Batch 10, Simulation 42 started...
#   Done in 3.45 seconds.
#
# Batch 10, Simulation 43 started...
#   Done in 3.41 seconds.
#
# Batch 10, Simulation 44 started...
#   Done in 3.81 seconds.
#
# Batch 10, Simulation 45 started...
#   Done in 3.94 seconds.
#
# Batch 10, Simulation 46 started...
#   Done in 3.46 seconds.
#
# Batch 10, Simulation 47 started...
#   Done in 3.78 seconds.
#
# Batch 10, Simulation 48 started...
#   Done in 4.57 seconds.
#
# Batch 10, Simulation 49 started...
#   Done in 3.43 seconds.
#
# Batch 10, Simulation 50 started...
#   Done in 3.48 seconds.
#
# ✅ Batch 10 gespeichert unter: simulation_results_ADP_10_2024.json
