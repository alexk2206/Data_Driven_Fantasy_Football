# %% [markdown]
# <a href="https://colab.research.google.com/github/alexk2206/Data_Driven_Fantasy_Football/blob/dev/PULP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
file_path = 'https://raw.githubusercontent.com/alexk2206/Data_Driven_Fantasy_Football/refs/heads/dev/FantasyPros_2024_Overall_ADP_Rankings.csv'
df = pd.read_csv(file_path, on_bad_lines='skip')

def standardize_column_names(df):
    def standardize(col):
        col_lower = col.lower()
        if "player" in col_lower:
            return "Player"
        elif "avg" in col_lower:
            return "AVG"
        else:
            return col
    df.columns = [standardize(col) for col in df.columns]
    return df

df = standardize_column_names(df)

k = 0.02
df['Value'] = 1000 * np.exp(-k * (df['AVG'] - 1))
df['POS'] = df['POS'].str.replace('\d+', '', regex=True)
df
# Out:
#       Rank               Player Team  Bye  POS  ESPN  Sleeper    NFL  \
# 0      1.0  Christian McCaffrey   SF   9    RB   1.0      1.0    1.0
# 1      2.0          CeeDee Lamb  DAL    7   WR   3.0      3.0    2.0
# 2      3.0          Tyreek Hill  MIA    6   WR   4.0      2.0    3.0
# 3      4.0       Bijan Robinson  ATL   12   RB   2.0      6.0    8.0
# 4      5.0          Breece Hall  NYJ   12   RB   5.0      8.0    7.0
# ..     ...                  ...  ...  ...  ...   ...      ...    ...
# 937  945.0     Mitchell Tinsley  CIN   12   WR   NaN      NaN  895.0
# 938  947.0        Anthony Gould  IND   14   WR   NaN      NaN  899.0
# 939  948.0      Patrick Murtagh  NaN  NaN   TE   NaN      NaN  900.0
# 940    NaN                  NaN  NaN  NaN  NaN   NaN      NaN    NaN
# 941    NaN                  NaN  NaN  NaN  NaN   NaN      NaN    NaN
#
#      RTSports  FFC    AVG        Value
# 0         1.0  NaN    1.0  1000.000000
# 1         2.0  NaN    2.6   968.506582
# 2         3.0  NaN    3.2   956.953957
# 3         4.0  NaN    5.0   923.116346
# 4         5.0  NaN    5.4   915.760877
# ..        ...  ...    ...          ...
# 937       NaN  NaN  895.0     0.000017
# 938       NaN  NaN  899.0     0.000016
# 939       NaN  NaN  900.0     0.000016
# 940       NaN  NaN    NaN          NaN
# 941       NaN  NaN    NaN          NaN
#
# [942 rows x 12 columns]

# %%
df = df[['Player', 'Bye', 'POS', 'AVG', 'Value']].dropna()

# Only keep relevant positions
df = df[df['POS'].str.contains('QB|RB|WR|TE|K|DST', na=False)]

# NaN-Werte in AVG durch den maximalen Wert +1 ersetzen (als "undraftbare" Spieler markieren)
df['AVG'] = df['AVG'].fillna(df['AVG'].max() + 1)

print(f'Length of df: {len(df)}')
print(f'value count of POS: {df["POS"].value_counts()}')
print(f'df head: {df.head(20)}')
# Out:
# Length of df: 665
# value count of POS: POS
# WR     244
# RB     142
# TE     122
# QB      89
# K       36
# DST     32
# Name: count, dtype: int64
# df head:                  Player Bye POS   AVG        Value
# 0   Christian McCaffrey  9   RB   1.0  1000.000000
# 1           CeeDee Lamb   7  WR   2.6   968.506582
# 2           Tyreek Hill   6  WR   3.2   956.953957
# 3        Bijan Robinson  12  RB   5.0   923.116346
# 4           Breece Hall  12  RB   5.4   915.760877
# 5     Amon-Ra St. Brown   5  WR   6.2   901.225297
# 6         Ja'Marr Chase  12  WR   6.6   894.044258
# 7      Justin Jefferson   6  WR   7.0   886.920437
# 8        Saquon Barkley   5  RB   9.2   848.742022
# 9            A.J. Brown   5  WR  10.2   831.935804
# 10      Jonathan Taylor  14  RB  10.4   828.614707
# 11       Garrett Wilson  12  WR  12.4   796.124260
# 12         Jahmyr Gibbs   5  RB  12.8   789.780674
# 13           Puka Nacua   6  WR  14.2   767.973540
# 14       Kyren Williams   6  RB  16.0   740.818221
# 15  Marvin Harrison Jr.  11  WR  16.8   729.059450
# 16   Travis Etienne Jr.  12  RB  17.4   720.363020
# 17        Derrick Henry  14  RB  18.0   711.770323
# 18        Isiah Pacheco   6  RB  20.2   681.131427
# 19        Davante Adams   6  WR  22.0   657.046820

# %%
# !pip install pulp
import pulp
# Out:
# Collecting pulp
#   Downloading pulp-3.1.1-py3-none-any.whl.metadata (1.3 kB)
# Downloading pulp-3.1.1-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 37.5 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-3.1.1

# %%
# Konfiguration
number_of_teams = 12
roster_requirements = {'QB': 1, 'RB': 2, 'WR': 2, 'TE': 1, 'K': 1, 'DST': 1}
max_team_size = 15

# Initialisierung
teams = list(range(1, number_of_teams + 1))
rosters = {t: [] for t in teams}
roster_counts = {t: {pos: 0 for pos in roster_requirements} for t in teams}

# Draft-Reihenfolge (Snake Style)
draft_order = []
for r in range(max_team_size):
    draft_order += teams if r % 2 == 0 else reversed(teams)

# Schritt 1: Replacement-Level pro Position bestimmen
replacement_rank = {pos: number_of_teams * req for pos, req in roster_requirements.items()}

replacement_value = {}
for pos in roster_requirements:
    pos_players = df[df['POS'] == pos].sort_values(by="Value", ascending=False).reset_index(drop=True)
    idx = replacement_rank[pos] - 1  # Nullbasiert
    if idx < len(pos_players):
        replacement_value[pos] = pos_players.loc[idx, "Value"]
    else:
        replacement_value[pos] = pos_players["Value"].min()

# Schritt 2: VOR berechnen
df["VOR"] = df.apply(lambda row: row["Value"] - replacement_value[row["POS"]], axis=1)

# Datenvorbereitung
df["CombinedScore"] = 0.8 * df["Value"] + 0.2 * df["VOR"]
available_players = df.copy()
draft_history = []

# MIP-basierter Draft-Prozess
for pick_number, current_team in enumerate(draft_order, 1):
    # Aktuelle Team-Anforderungen
    current_roster = rosters[current_team]
    current_counts = roster_counts[current_team]

    # Positionsbedarf ermitteln
    needed_positions = [
        pos for pos, req in roster_requirements.items()
        if current_counts[pos] < req
    ]

    # Modell erstellen
    model = pulp.LpProblem(f"Draft_Pick_{pick_number}", pulp.LpMaximize)

    # Entscheidungsvariablen
    players = available_players['Player'].tolist()
    x = pulp.LpVariable.dicts("Draft", players, cat='Binary')

    # Zielfunktion (maximiere Combined Score)
    model += pulp.lpSum(
        x[p] * available_players.loc[available_players['Player'] == p, 'CombinedScore'].values[0]
        for p in players
    )

    # Nebenbedingungen
    ## Genau 1 Spieler pro Pick
    model += pulp.lpSum(x.values()) == 1

    ## Positionsbeschränkungen
    if needed_positions:
        model += pulp.lpSum(
            x[p] for p in available_players[
                available_players['POS'].isin(needed_positions)
            ]['Player']
        ) >= 1

    ## Gesamtteamgröße
    model += pulp.lpSum(x.values()) <= (max_team_size - len(current_roster))

    # Problem lösen
    model.solve(pulp.PULP_CBC_CMD(msg=0))

    # Ergebnis verarbeiten
    drafted_player = next(
        p for p in players
        if pulp.value(x[p]) == 1
    )

    player_data = available_players[available_players['Player'] == drafted_player].iloc[0]

    # Roster aktualisieren
    rosters[current_team].append({
        'Player': drafted_player,
        'POS': player_data['POS'],
        'Value': player_data['Value'],
        'VOR': player_data['VOR'],
        'CombinedScore': player_data['CombinedScore']
    })
    roster_counts[current_team][player_data['POS']] += 1

    # Spieler aus Available entfernen
    available_players = available_players[available_players['Player'] != drafted_player]

    # Draft-Historie speichern
    draft_history.append({
        'Pick': pick_number,
        'Team': current_team,
        'Player': drafted_player,
        'POS': player_data['POS'],
        'Value': player_data['Value'],
        'VOR': player_data['VOR']
    })

# Ergebnisse darstellen
draft_df = pd.DataFrame(draft_history)

print("\nDraft Verlauf:")
print(draft_df[['Pick', 'Team', 'Player', 'POS', 'Value']].to_string(index=False))

print("\nTeam Rosters:")
for team in teams:
    team_df = pd.DataFrame(rosters[team])
    team_value = team_df['Value'].sum()
    print(f"\nTeam {team} (Gesamtwert: {team_value:.1f}):")
    print(team_df[['Player', 'POS', 'Value']].to_string(index=False))
# Out:
# Draft Verlauf:
#  Pick  Team                 Player POS       Value
#     1     1    Christian McCaffrey  RB 1000.000000
#     2     2            CeeDee Lamb  WR  968.506582
#     3     3            Tyreek Hill  WR  956.953957
#     4     4         Bijan Robinson  RB  923.116346
#     5     5            Breece Hall  RB  915.760877
#     6     6      Amon-Ra St. Brown  WR  901.225297
#     7     7          Ja'Marr Chase  WR  894.044258
#     8     8       Justin Jefferson  WR  886.920437
#     9     9         Saquon Barkley  RB  848.742022
#    10    10        Jonathan Taylor  RB  828.614707
#    11    11             A.J. Brown  WR  831.935804
#    12    12           Jahmyr Gibbs  RB  789.780674
#    13    12         Garrett Wilson  WR  796.124260
#    14    11         Kyren Williams  RB  740.818221
#    15    10             Puka Nacua  WR  767.973540
#    16     9     Travis Etienne Jr.  RB  720.363020
#    17     8          Derrick Henry  RB  711.770323
#    18     7    Marvin Harrison Jr.  WR  729.059450
#    19     6          Isiah Pacheco  RB  681.131427
#    20     5             Josh Allen  QB  628.763554
#    21     4           Travis Kelce  TE  616.313202
#    22     3          Davante Adams  WR  657.046820
#    23     2     Patrick Mahomes II  QB  571.209064
#    24     1          De'Von Achane  RB  589.783358
#    25     1           Drake London  WR  611.402366
#    26     2            Josh Jacobs  RB  580.421915
#    27     3            Jalen Hurts  QB  546.620774
#    28     4            Chris Olave  WR  604.109383
#    29     5            Sam LaPorta  TE  540.100525
#    30     6           Nico Collins  WR  580.421915
#    31     7             James Cook  RB  548.811636
#    32     8          Rachaad White  RB  542.265253
#    33     9             Mike Evans  WR  546.620774
#    34    10       Deebo Samuel Sr.  WR  537.944438
#    35    11          Lamar Jackson  QB  484.809136
#    36    12          Brandon Aiyuk  WR  516.851334
#    37    12              Joe Mixon  RB  471.422764
#    38    11    Michael Pittman Jr.  WR  510.686183
#    39    10           Alvin Kamara  RB  462.087968
#    40     9            Cooper Kupp  WR  508.647519
#    41     8           Mark Andrews  TE  408.199195
#    42     7     Kenneth Walker III  RB  445.748673
#    43     6           Trey McBride  TE  403.330078
#    44     5             DK Metcalf  WR  447.535238
#    45     4            C.J. Stroud  QB  385.968314
#    46     3         Dalton Kincaid  TE  349.238573
#    47     2          Jaylen Waddle  WR  435.178059
#    48     1           Stefon Diggs  WR  431.710523
#    49     1          George Kittle  TE  328.900502
#    50     2           James Conner  RB  332.871084
#    51     3        Aaron Jones Sr.  RB  312.234741
#    52     4               DJ Moore  WR  426.560956
#    53     5          DeVonta Smith  WR  423.162082
#    54     6 Anthony Richardson Sr.  QB  322.387836
#    55     7             Joe Burrow  QB  296.413453
#    56     8           Malik Nabers  WR  385.968314
#    57     9             Kyle Pitts  TE  282.521677
#    58    10            Evan Engram  TE  278.037300
#    59    11          D'Andre Swift  RB  303.613430
#    60    12           Dak Prescott  QB  259.759260
#    61    12          Jake Ferguson  TE  199.488238
#    62    11            David Njoku  TE  189.379943
#    63    10           Kyler Murray  QB  250.574249
#    64     9            Jordan Love  QB  244.632058
#    65     8            Brock Purdy  QB  162.675152
#    66     7           Brock Bowers  TE  136.422308
#    67     6       David Montgomery  RB  296.413453
#    68     5            Zamir White  RB  269.280956
#    69     4    Rhamondre Stevenson  RB  269.280956
#    70     3           Najee Harris  RB  247.585327
#    71     2          Justin Tucker   K  116.717359
#    72     1         Jayden Daniels  QB  131.073113
#    73     1        Harrison Butker   K  108.175540
#    74     2    San Francisco 49ers DST  100.258844
#    75     3         Brandon Aubrey   K  105.610234
#    76     4         Dallas Cowboys DST   78.866400
#    77     5       Baltimore Ravens DST   78.551564
#    78     6          New York Jets DST   78.237986
#    79     7       Cleveland Browns DST   69.113859
#    80     8           Younghoe Koo   K   62.038507
#    81     9           Jake Elliott   K   55.687476
#    82    10       Ka'imi Fairbairn   K   51.818917
#    83    11         Evan McPherson   K   51.612056
#    84    12             Jake Moody   K   44.511843
#    85    12    Pittsburgh Steelers DST   42.766508
#    86    11     Cincinnati Bengals DST   41.752331
#    87    10     Kansas City Chiefs DST   41.585655
#    88     9          Buffalo Bills DST   37.779071
#    89     8         Miami Dolphins DST   32.975184
#    90     7         Dustin Hopkins   K   42.003598
#    91     6         Cameron Dicker   K   36.297733
#    92     5          Greg Zuerlein   K   26.890022
#    93     4             Tyler Bass   K   26.043163
#    94     3    Philadelphia Eagles DST   28.667248
#    95     2         Dallas Goedert  TE  113.949490
#    96     1         Houston Texans DST   25.732513
#    97     1         George Pickens  WR  309.746828
#    98     2            Tee Higgins  WR  294.051605
#    99     3            Zay Flowers  WR  288.228993
#   100     4              Tank Dell  WR  278.037300
#   101     5            Rashee Rice  WR  263.948835
#   102     6         Raheem Mostert  RB  229.466094
#   103     7         Terry McLaurin  WR  243.655485
#   104     8          Calvin Ridley  WR  230.385796
#   105     9         Christian Kirk  WR  229.466094
#   106    10       Javonte Williams  RB  201.090545
#   107    11           Tony Pollard  RB  198.691879
#   108    12           Chris Godwin  WR  222.239422
#   109    12          Austin Ekeler  RB  165.298888
#   110    11     Brian Robinson Jr.  RB  160.093061
#   111    10          Jaylen Warren  RB  160.093061
#   112     9       Devin Singletary  RB  154.432218
#   113     8            Jayden Reed  WR  178.351314
#   114     7        Diontae Johnson  WR  174.819721
#   115     6              Zack Moss  RB  143.703950
#   116     5          Xavier Worthy  WR  168.638147
#   117     4         Caleb Williams  QB  115.325121
#   118     3           Tyjae Spears  RB  137.518063
#   119     2        Jonathon Brooks  RB  134.256920
#   120     1         Tua Tagovailoa  QB  100.660682
#   121     1             Jared Goff  QB  100.258844
#   122     2            Rome Odunze  WR  142.558904
#   123     3     Jaxon Smith-Njigba  WR  138.622620
#   124     4            Chase Brown  RB  110.360831
#   125     5         Dalton Schultz  TE   82.744312
#   126     6         T.J. Hockenson  TE   81.430938
#   127     7            Jerome Ford  RB  106.458504
#   128     8       Christian Watson  WR  132.125903
#   129     9        Trevor Lawrence  QB   76.688770
#   130    10           Keon Coleman  WR  125.933662
#   131    11         Justin Herbert  QB   74.571268
#   132    12          Ladd McConkey  WR  123.934758
#   133    12         Pat Freiermuth  TE   68.016837
#   134    11        DeAndre Hopkins  WR  118.599857
#   135    10              Cole Kmet  TE   60.810063
#   136     9         Marquise Brown  WR  112.590268
#   137     8         Jordan Addison  WR  112.140806
#   138     7           Kirk Cousins  QB   58.894946
#   139     6       Courtland Sutton  WR  107.743702
#   140     5            Blake Corum  RB   78.866400
#   141     4       Matthew Stafford  QB   50.186962
#   142     3          Chuba Hubbard  RB   72.222763
#   143     2       Brian Thomas Jr.  WR   99.858609
#   144     1            Trey Benson  RB   70.510052
#   145     1      Arizona Cardinals DST   24.477523
#   146     2          Chris Boswell   K   24.477523
#   147     3          Chicago Bears DST   24.040870
#   148     4         Denver Broncos DST   22.236949
#   149     5     New Orleans Saints DST   21.152440
#   150     6            Taysom Hill  TE   38.006427
#   151     7       Jameson Williams  WR   92.181115
#   152     8            Jason Myers   K   20.080622
#   153     9   Tampa Bay Buccaneers DST   19.604424
#   154    10          Jason Sanders   K   18.911218
#   155    11         Daniel Carlson   K   18.389048
#   156    12               Matt Gay   K   18.315639
#   157    12           Cairo Santos   K   17.952965
#   158    11         Deshaun Watson  QB   38.542259
#   159    10       Seattle Seahawks DST   16.705789
#   160     9          Detroit Lions DST   16.572675
#   161     8          Luke Musgrave  TE   34.183917
#   162     7        Atlanta Falcons DST   15.827600
#   163     6         Baker Mayfield  QB   36.443214
#   164     5      Las Vegas Raiders DST   14.757557
#   165     4             Jake Bates   K   14.122302
#   166     3  Washington Commanders DST   13.220323
#   167     2     Indianapolis Colts DST   12.829604
#   168     1          Will Reichard   K   12.450431
#   169     1      Green Bay Packers DST   11.962243
#   170     2   New England Patriots DST   11.866927
#   171     3            Graham Gano   K   10.889024
#   172     4   Los Angeles Chargers DST   10.254896
#   173     5               Wil Lutz   K   10.254896
#   174     6          Isaiah Likely  TE   27.764418
#   175     7        New York Giants DST   10.092124
#   176     8            Blake Grupe   K   10.051836
#   177     9      Minnesota Vikings DST    9.561602
#   178    10   Jacksonville Jaguars DST    9.466462
#   179    11          Tyler Conklin  TE   26.782676
#   180    12        Zach Charbonnet  RB   53.503939
#
# Team Rosters:
#
# Team 1 (Gesamtwert: 3856.8):
#              Player POS       Value
# Christian McCaffrey  RB 1000.000000
#       De'Von Achane  RB  589.783358
#        Drake London  WR  611.402366
#        Stefon Diggs  WR  431.710523
#       George Kittle  TE  328.900502
#      Jayden Daniels  QB  131.073113
#     Harrison Butker   K  108.175540
#      Houston Texans DST   25.732513
#      George Pickens  WR  309.746828
#      Tua Tagovailoa  QB  100.660682
#          Jared Goff  QB  100.258844
#         Trey Benson  RB   70.510052
#   Arizona Cardinals DST   24.477523
#       Will Reichard   K   12.450431
#   Green Bay Packers DST   11.962243
#
# Team 2 (Gesamtwert: 3939.0):
#               Player POS      Value
#          CeeDee Lamb  WR 968.506582
#   Patrick Mahomes II  QB 571.209064
#          Josh Jacobs  RB 580.421915
#        Jaylen Waddle  WR 435.178059
#         James Conner  RB 332.871084
#        Justin Tucker   K 116.717359
#  San Francisco 49ers DST 100.258844
#       Dallas Goedert  TE 113.949490
#          Tee Higgins  WR 294.051605
#      Jonathon Brooks  RB 134.256920
#          Rome Odunze  WR 142.558904
#     Brian Thomas Jr.  WR  99.858609
#        Chris Boswell   K  24.477523
#   Indianapolis Colts DST  12.829604
# New England Patriots DST  11.866927
#
# Team 3 (Gesamtwert: 3888.7):
#                Player POS      Value
#           Tyreek Hill  WR 956.953957
#         Davante Adams  WR 657.046820
#           Jalen Hurts  QB 546.620774
#        Dalton Kincaid  TE 349.238573
#       Aaron Jones Sr.  RB 312.234741
#          Najee Harris  RB 247.585327
#        Brandon Aubrey   K 105.610234
#   Philadelphia Eagles DST  28.667248
#           Zay Flowers  WR 288.228993
#          Tyjae Spears  RB 137.518063
#    Jaxon Smith-Njigba  WR 138.622620
#         Chuba Hubbard  RB  72.222763
#         Chicago Bears DST  24.040870
# Washington Commanders DST  13.220323
#           Graham Gano   K  10.889024
#
# Team 4 (Gesamtwert: 3930.8):
#               Player POS      Value
#       Bijan Robinson  RB 923.116346
#         Travis Kelce  TE 616.313202
#          Chris Olave  WR 604.109383
#          C.J. Stroud  QB 385.968314
#             DJ Moore  WR 426.560956
#  Rhamondre Stevenson  RB 269.280956
#       Dallas Cowboys DST  78.866400
#           Tyler Bass   K  26.043163
#            Tank Dell  WR 278.037300
#       Caleb Williams  QB 115.325121
#          Chase Brown  RB 110.360831
#     Matthew Stafford  QB  50.186962
#       Denver Broncos DST  22.236949
#           Jake Bates   K  14.122302
# Los Angeles Chargers DST  10.254896
#
# Team 5 (Gesamtwert: 3970.4):
#             Player POS      Value
#        Breece Hall  RB 915.760877
#         Josh Allen  QB 628.763554
#        Sam LaPorta  TE 540.100525
#         DK Metcalf  WR 447.535238
#      DeVonta Smith  WR 423.162082
#        Zamir White  RB 269.280956
#   Baltimore Ravens DST  78.551564
#      Greg Zuerlein   K  26.890022
#        Rashee Rice  WR 263.948835
#      Xavier Worthy  WR 168.638147
#     Dalton Schultz  TE  82.744312
#        Blake Corum  RB  78.866400
# New Orleans Saints DST  21.152440
#  Las Vegas Raiders DST  14.757557
#           Wil Lutz   K  10.254896
#
# Team 6 (Gesamtwert: 3964.0):
#                 Player POS      Value
#      Amon-Ra St. Brown  WR 901.225297
#          Isiah Pacheco  RB 681.131427
#           Nico Collins  WR 580.421915
#           Trey McBride  TE 403.330078
# Anthony Richardson Sr.  QB 322.387836
#       David Montgomery  RB 296.413453
#          New York Jets DST  78.237986
#         Cameron Dicker   K  36.297733
#         Raheem Mostert  RB 229.466094
#              Zack Moss  RB 143.703950
#         T.J. Hockenson  TE  81.430938
#       Courtland Sutton  WR 107.743702
#            Taysom Hill  TE  38.006427
#         Baker Mayfield  QB  36.443214
#          Isaiah Likely  TE  27.764418
#
# Team 7 (Gesamtwert: 3863.5):
#              Player POS      Value
#       Ja'Marr Chase  WR 894.044258
# Marvin Harrison Jr.  WR 729.059450
#          James Cook  RB 548.811636
#  Kenneth Walker III  RB 445.748673
#          Joe Burrow  QB 296.413453
#        Brock Bowers  TE 136.422308
#    Cleveland Browns DST  69.113859
#      Dustin Hopkins   K  42.003598
#      Terry McLaurin  WR 243.655485
#     Diontae Johnson  WR 174.819721
#         Jerome Ford  RB 106.458504
#        Kirk Cousins  QB  58.894946
#    Jameson Williams  WR  92.181115
#     Atlanta Falcons DST  15.827600
#     New York Giants DST  10.092124
#
# Team 8 (Gesamtwert: 3910.1):
#           Player POS      Value
# Justin Jefferson  WR 886.920437
#    Derrick Henry  RB 711.770323
#    Rachaad White  RB 542.265253
#     Mark Andrews  TE 408.199195
#     Malik Nabers  WR 385.968314
#      Brock Purdy  QB 162.675152
#     Younghoe Koo   K  62.038507
#   Miami Dolphins DST  32.975184
#    Calvin Ridley  WR 230.385796
#      Jayden Reed  WR 178.351314
# Christian Watson  WR 132.125903
#   Jordan Addison  WR 112.140806
#      Jason Myers   K  20.080622
#    Luke Musgrave  TE  34.183917
#      Blake Grupe   K  10.051836
#
# Team 9 (Gesamtwert: 3863.9):
#               Player POS      Value
#       Saquon Barkley  RB 848.742022
#   Travis Etienne Jr.  RB 720.363020
#           Mike Evans  WR 546.620774
#          Cooper Kupp  WR 508.647519
#           Kyle Pitts  TE 282.521677
#          Jordan Love  QB 244.632058
#         Jake Elliott   K  55.687476
#        Buffalo Bills DST  37.779071
#       Christian Kirk  WR 229.466094
#     Devin Singletary  RB 154.432218
#      Trevor Lawrence  QB  76.688770
#       Marquise Brown  WR 112.590268
# Tampa Bay Buccaneers DST  19.604424
#        Detroit Lions DST  16.572675
#    Minnesota Vikings DST   9.561602
#
# Team 10 (Gesamtwert: 3811.6):
#               Player POS      Value
#      Jonathan Taylor  RB 828.614707
#           Puka Nacua  WR 767.973540
#     Deebo Samuel Sr.  WR 537.944438
#         Alvin Kamara  RB 462.087968
#          Evan Engram  TE 278.037300
#         Kyler Murray  QB 250.574249
#     Ka'imi Fairbairn   K  51.818917
#   Kansas City Chiefs DST  41.585655
#     Javonte Williams  RB 201.090545
#        Jaylen Warren  RB 160.093061
#         Keon Coleman  WR 125.933662
#            Cole Kmet  TE  60.810063
#        Jason Sanders   K  18.911218
#     Seattle Seahawks DST  16.705789
# Jacksonville Jaguars DST   9.466462
#
# Team 11 (Gesamtwert: 3790.3):
#              Player POS      Value
#          A.J. Brown  WR 831.935804
#      Kyren Williams  RB 740.818221
#       Lamar Jackson  QB 484.809136
# Michael Pittman Jr.  WR 510.686183
#       D'Andre Swift  RB 303.613430
#         David Njoku  TE 189.379943
#      Evan McPherson   K  51.612056
#  Cincinnati Bengals DST  41.752331
#        Tony Pollard  RB 198.691879
#  Brian Robinson Jr.  RB 160.093061
#      Justin Herbert  QB  74.571268
#     DeAndre Hopkins  WR 118.599857
#      Daniel Carlson   K  18.389048
#      Deshaun Watson  QB  38.542259
#       Tyler Conklin  TE  26.782676
#
# Team 12 (Gesamtwert: 3790.0):
#              Player POS      Value
#        Jahmyr Gibbs  RB 789.780674
#      Garrett Wilson  WR 796.124260
#       Brandon Aiyuk  WR 516.851334
#           Joe Mixon  RB 471.422764
#        Dak Prescott  QB 259.759260
#       Jake Ferguson  TE 199.488238
#          Jake Moody   K  44.511843
# Pittsburgh Steelers DST  42.766508
#        Chris Godwin  WR 222.239422
#       Austin Ekeler  RB 165.298888
#       Ladd McConkey  WR 123.934758
#      Pat Freiermuth  TE  68.016837
#            Matt Gay   K  18.315639
#        Cairo Santos   K  17.952965
#     Zach Charbonnet  RB  53.503939
